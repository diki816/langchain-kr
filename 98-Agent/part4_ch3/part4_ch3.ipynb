# %% [markdown]
# 뉴스레터 멀티 |에이전트 만들어보기

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from tavily import TavilyClient
import os
from langchain_core.tools import tool

tavily_client = TavilyClient()

def search_recent_news(keyword):
    """
    This tool interacts with the Tavily AI API to search for recent news articles related to a given keyword.

    Args:
        keyword (str): The keyword or phrase to search for in the news articles.
    
    Returns:
        list:
            A list of titles, each containing up to 10 of the most recent news articles related to the keyword.
            If the content of news articles smilar with others, replace it with new article.
            - 'title' (str): The title of the news article.
    
    Example:
        response = search_news("OpenAI")
        # Returns a list of news articles published in the last day related to OpenAI.
    """
    article_info = []

    response = tavily_client.search(
        query=keyword,
        max_results=10,
        topic="news",
        days=7
    )

    title_list = [i['title'] for i in response['results']]
    return title_list

# %%
result = search_recent_news("Negotiations between the United States and Ukraine")
# result

# %%
from pydantic import BaseModel, Field
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

llm = ChatOpenAI(model="gpt-4o-mini", temperature=1)

class NewsletterThemeOutput(BaseModel):
    """Output model for structured theme and sub-theme generation."""
    theme: str = Field(
        description="The main newsletter theme based on the provided article titles."
    )
    sub_themes: list[str] = Field(
        description="List of sub-themes or key news itmes to investigate under the main theme, ensuring they are specific and researchable"
    )

structured_llm_newsletter = llm.with_structured_output(NewsletterThemeOutput)

# print(structured_llm_newsletter)

system = """
You are an expert helping to create a newsletter.
Based on a list of article titles provided, your task is to choose a single,
specific newsletter theme framed as a clear, detailed question that grabs the reader's attention.

In addition, generate 5 sub-themes that are highly specific, researchable news items or insights under the main theme.
Ensure these sub-themes reflect the lastest trends in the field and frame them as compelling news topics.

The output should be formatedd as:
- Main theme (in question form)
- 3-5 sub-themes (detailed and focused on emerging trends, technologies, or insights)

The sub-themes should create a clear direction for the newsletter, avoiding broad, generic topics.
All your output should be in English
"""

theme_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system),
        ("human", "Article titles: \n\n {article_titles}"),
    ]
)

newsletter_generator = theme_prompt | structured_llm_newsletter

# %%
output= newsletter_generator.invoke({"article_titles": result})
subthemes = output.sub_themes
output
# Out:
# NewsletterThemeOutput(theme='How are US-Ukraine mineral deals influencing global geopolitics and economic stability?', sub_themes=['The Strategic Importance of Rare Earth Minerals: How US-Ukraine Deals Align with Global Supply Chain Needs', 'Negotiations Under Pressure: Examining the Impact of Russian Military Actions on US-Ukraine Mineral Agreements', "Zelenskyy's Diplomatic Dance: Analyzing the White House Meetings with Trump and Their Implications for US-Ukraine Relations", 'Long-term Agreements and Their Economic Implications: What the Newly Signed Deals Mean for the Future of US-Ukraine Ties', 'Public and Political Reactions: How International and Domestic Sentiments Surround the US-Ukraine Mineral Trade Affect Broader Geopolitical Dynamics'])

# %%
from typing import List

def subtheme_generator(recent_news: List[str]):
    
    llm = ChatOpenAI(model="gpt-4o-mini", temperature=1)

    class NewsletterThemeOutput(BaseModel):
        """Output model for structured theme and sub-theme generation."""
        theme: str = Field(
            description="The main newsletter theme based on the provided article titles."
        )
        sub_themes: list[str] = Field(
            description="List of sub-themes or key news itmes to investigate under the main theme, ensuring they are specific and researchable"
        )

    structured_llm_newsletter = llm.with_structured_output(NewsletterThemeOutput)

    system = """
    You are an expert helping to create a newsletter.
    Based on a list of article titles provided, your task is to choose a single,
    specific newsletter theme framed as a clear, detailed question that grabs the reader's attention.

    In addition, generate 5 sub-themes that are highly specific, researchable news items or insights under the main theme.
    Ensure these sub-themes reflect the lastest trends in the field and frame them as compelling news topics.

    The output should be formatedd as:
    - Main theme (in question form)
    - 3-5 sub-themes (detailed and focused on emerging trends, technologies, or insights)

    The sub-themes should create a clear direction for the newsletter, avoiding broad, generic topics.
    All your output should be in English
    """

    theme_prompt = ChatPromptTemplate.from_messages(
        [
            ("system", system),
            ("human", "Article titles: \n\n {recent_news}"),
        ]
    )
    subtheme_chain = theme_prompt | structured_llm_newsletter
    output = subtheme_chain.invoke({"recent_news": recent_news})
    return output

# %%
output = subtheme_generator({"article_titles":result})
subthemes = output.sub_themes
output
# Out:
# NewsletterThemeOutput(theme='How will upcoming U.S.-Ukraine negotiations reshape geopolitical alliances and mineral resource management?', sub_themes=['Analyzing the strategic implications of U.S. mineral deals with Ukraine in the context of global supply chains.', "The role of U.S. support in Ukraine's energy independence and its impact on Russian retaliation.", 'Investigating the potential long-term economic impacts of U.S.-Ukraine agreements on Eastern European stability.', "Decoding the political dynamics of Zelenskyy's engagement with Trump amid evolving peace talks and mineral negotiations.", 'Evaluating how recent military actions influence U.S.-Ukraine negotiations and potential future agreements.'])

# %%
# Test
from tavily import AsyncTavilyClient

async_tavily_client = AsyncTavilyClient()
response = await async_tavily_client.search(
        query="미국의 광물 자원 지원이 우크라이나 경제에 미치는 영향: 장기적인 관점에서의 분석",
        max_result=5,
        topic="news",
        days=3,
        include_images=True,
        include_raw_content=True,
    )

response
# print(os.getenv("TAVILY_API_KEY"))

# %%
import asyncio
from typing import Dict, List, TypedDict, Annotated
from tavily import AsyncTavilyClient

# async_tavily_client = AsyncTavilyClient(api_key="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")
async_tavily_client = AsyncTavilyClient()

async def search_news_for_subtheme(subtheme):
    """
    Searches for news articles related to the given subtheme.
    """
    response = await async_tavily_client.search(
    # response = tavily_client.search(
        query=subtheme,
        max_result=5,
        topic="news",
        days=3,
        include_images=True,
        include_raw_content=True,
    )
    images = response['images']
    results = response['results']

    article_info = []
    for i, result in enumerate(results):
        article_info.append({
            'title': result['title'],
            'image_url': images[i],
            'raw_content': result['raw_content']
        })
    
    return {subtheme: article_info}

async def search_news_by_subthemes(subthemes):
    # asyncio.gather에서 지속적으로 exception이 일어남
    results = await asyncio.gather(*[search_news_for_subtheme(subtheme) for subtheme in subthemes])
    search_results = {}
    for result in results:
    # for subtheme in subthemes:
        # result = await search_news_for_subtheme(subtheme)
        search_results.update(result)
    
    return search_results

# %%
# for subtheme in subthemes:
#     result = await search_news_for_subtheme(subtheme)
# search_results

# %%
# subthemes
subtheme_search_results = await search_news_by_subthemes(subthemes)
subtheme_search_results

# %%
# 개발용, 밑에 머지됨
from langgraph.graph.message import add_messages
from langchain_core.messages import HumanMessage, AIMessage

def merge_dicts(left: Dict, right: Dict) -> Dict:
    return {**left, **right}

class State(TypedDict):
    keyword: str
    article_titles: List[str]
    newsletter_theme: NewsletterThemeOutput
    sub_theme_articles: Dict[str, List[Dict]]
    results: Annotated[Dict[str, str], merge_dicts]
    messages: Annotated[List, add_messages]

def write_newsletter_section_async(state: State, sub_theme: str) -> Dict:
    articles = state['sub_theme_articles'][sub_theme]

    article_references = "\n".join(
        [f"Title: {article['title']} \nContent: {article['raw_content']}..."
        for article in articles]
    )

    prompt = f"""
    Write a newletter section for the sub-theme: "{sub_theme}".

    Use the following articles as reference and include relevant points from both their titles, images, and content:
    <article>
    {article_references}
    </article>
    Summarize the key points and trends related to this sub-theme, and ensure you reference the images where they add value to the discussion.
    Keepy the tone engaging and informative for newsletter readers. You should write in Korean.
    """

    messages = [HumanMessage(content=prompt)]
    response = llm.invoke(messages)
    return {"results": {sub_theme: response.content}}

def write_newsletter_section(state: State, sub_theme: str) -> Dict:
    return asyncio.run(write_newsletter_section_async(state, sub_theme))

# %%
test_state = {
    'sub_theme_articles': {
        "Navigating the Politics of Mineral Extraction: How US Legislative Support is Influencing Ukraine's Economy and Security Strategy":
        subtheme_search_results["Navigating the Politics of Mineral Extraction: How US Legislative Support is Influencing Ukraine's Economy and Security Strategy"]
    },
    'results': {}
}
write_newsletter_section_async(test_state, "Navigating the Politics of Mineral Extraction: How US Legislative Support is Influencing Ukraine's Economy and Security Strategy")
# Out:
# {'results': {"Navigating the Politics of Mineral Extraction: How US Legislative Support is Influencing Ukraine's Economy and Security Strategy": '## 뉴스레터 섹션: "광물 채취의 정치적 항해: 미국의 입법 지원이 우크라이나의 경제 및 안보 전략에 미치는 영향"\n\n우크라이나와 미국 간의 협력 강화가 앞으로의 정치적 및 경제적 전환점이 되며, 이에 대한 여러 뉴스가 발표되고 있습니다. 우크라이나의 볼로디미르 젤렌스키 대통령이 도널드 트럼프 대통령과의 회담을 위해 워싱턴 D.C.를 방문했습니다. 해당 회담에서 두 정상은 우크라이나의 경제 재건을 위한 혁신적인 협정에 서명할 예정이며, 이 협정은 두 나라 간의 관계를 더욱 밀접하게 만들어줄 것으로 기대됩니다.\n\n### 불확실성과 가능성\n\n2025년 2월 26일자 뉴욕 타임즈 기사에서 다룬 바와 같이, 미국과 우크라이나 간의 광물 자원에 대한 협정 초안에는 우크라이나의 광물 자원을 공동 관리하는 투자 기금 설립이 포함되어 있습니다. 이 기금은 우크라이나가 자원으로부터 얻는 수익의 50%를 기여할 것으로 예상됩니다. 그러나 이 협정에는 트럼프 행정부가 처음 요구했던 5,000억 달러의 우크라이나 자산 기여 요구사항은 포함되지 않았습니다.\n\n이와 관련하여, 젤렌스키 대통령은 안전 보장과 경제적 지원 모두가 필수적이라고 강조했습니다. 그는 회담에서 미국의 군사적 지원이 필요하다고 언급하며, 이러한 협정이 우크라이나의 안보를 실질적으로 보장해야 한다고 주장했습니다. 젤렌스키는 특히 “이 협정이 미래의 안전 보장과 연결되어 있다”는 점을 분명히 했습니다.\n\n### 유럽 차원의 관심\n\n유럽연합의 많은 지도자들도 우크라이나의 자원에 대한 관심을 보이고 있으며, 영국의 키어 스타머 총리와 프랑스의 에마뉘엘 마크롱 대통령은 우크라이나의 평화 유지 임무에 대한 제안을 준비했습니다. 이는 미국 없이 유럽이 우크라이나의 평화를 지키는 것의 필요성을 보여줍니다.\n\n### 광물의 중요성과 복잡성\n\n우크라이나는 세계에서 중요한 광물 자원을 많이 보유하고 있으며, 특히 리튬, 코발트, 타이타늄 등의 자원은 산업계에서 큰 수요를 받고 있습니다. 하지만 이 자원들이 주요 국가의 통제 하에 있는 만큼, 복잡한 지정학적 상황과 내부 문제들이 해결되지 않는 한 원활한 자원 추출은 어려울 것으로 예상됩니다.\n\n우크라이나의 자원 추출은 비용이 많이 드는 작업이며, 초기 조사에 따르면 최소 150억 달러가 필요하다고 합니다. 이는 전쟁으로 인한 인프라의 파손을 고려할 때 더욱 복잡해지며, 트럼프 대통령이 예상하는 "자동적인 안전 보장"이 현실화되기 위해서는 추가적인 투자가 필수적입니다.\n\n### 시각적 요소\n\n보도된 기사들 중, 북한에서 채굴하는 대형 기계가 우크라이나의 자원의 채취를 위해 작동하는 모습이 담긴 사진은 이러한 상황의 중대성을 더욱 부각시킵니다. 이는 분쟁 중에도 광물 자원을 얻기 위한 노력이 지속되고 있음을 의미하며, 이러한 노력의 결과로써 협정이 결실을 볼 수 있을지에 대한 기대감을 나타냅니다.\n\n결국, 우크라이나와 미국 간의 새로운 협력관계는 양국의 경제에 중요한 영향을 미칠 것으로 보이며, 이 과정에서 안보 문제도 중요한 요소로 얽혀있습니다. 향후 협상이 어떻게 진행될지, 그리고 이 협정이 실제로 우크라이나의 경제에 긍정적인 변화를 가져올 수 있을지 주목해야 할 시점입니다.'}}

# %%
from langchain_anthropic import ChatAnthropic
from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages
from langchain_core.messages import HumanMessage, AIMessage
import operator
import os

def merge_dicts(left: Dict, right: Dict) -> Dict:
    return {**left, **right}

class State(TypedDict):
    keyword: str
    article_titles: List[str]
    newsletter_theme: NewsletterThemeOutput
    sub_theme_articles: Dict[str, List[Dict]]
    results: Annotated[Dict[str, str], merge_dicts]
    messages: Annotated[List, add_messages]

def search_keyword_news(state: State) -> State:
    keyword = state['keyword']
    article_titles = search_recent_news(keyword)
    return {"article_titles": article_titles}

def generate_newsletter_theme(state: State) -> State:
    article_titles = state['article_titles']
    newsletter_theme = newsletter_generator.invoke({"article_titles": "\n".join(article_titles)})
    newsletter_theme.sub_themes = newsletter_theme.sub_themes[:5]
    return {"newsletter_theme": newsletter_theme}


async def search_sub_theme_articles(state: State) -> State:
    # asyncio.gather에서 지속적으로 exception이 일어남
    subthemes = state['newsletter_theme'].sub_themes
    results = await asyncio.gather(*[search_news_for_subtheme(subtheme) for subtheme in subthemes])
    search_results = {}
    for result in results:
    # for subtheme in subthemes:
        # result = await search_news_for_subtheme(subtheme)
        search_results.update(result)
    
    return {"sub_theme_articles": search_results}

async def write_newsletter_section_async(state: State, sub_theme: str) -> Dict:
    articles = state['sub_theme_articles'][sub_theme]

    article_references = "\n".join(
        [f"Title: {article['title']} \nContent: {article['raw_content']}..."
        for article in articles]
    )

    prompt = f"""
    Write a newletter section for the sub-theme: "{sub_theme}".

    Use the following articles as reference and include relevant points from both their titles, images, and content:
    <article>
    {article_references}
    </article>
    Summarize the key points and trends related to this sub-theme, and ensure you reference the images where they add value to the discussion.
    Keepy the tone engaging and informative for newsletter readers. You should write in Korean.
    """

    messages = [HumanMessage(content=prompt)]
    response = await llm.ainvoke(messages)
    return {"results": {sub_theme: response.content}}

def write_newsletter_section(state: State, sub_theme: str) -> Dict:
    return asyncio.run(write_newsletter_section_async(state, sub_theme))

def aggregate_results(state: State) -> State:
    theme = state['newsletter_theme'].theme
    combined_newsletter = f"# {theme}\n\n"
    
    for sub_theme, content in state['results'].items():
        combined_newsletter += f"## {sub_theme}\n{content}\n\n"
    return {"messages": [HumanMessage(content=f"Generated Newsletter:\n\n{combined_newsletter}")]}

def edit_newsletter(state: State) -> State:
    theme = state['newsletter_theme'].theme
    combined_newsletter = state['messages'][-1].content

    prompt = f"""
    As an expert editor, review and refine the following newsletter on the theme: {theme}

    {combined_newsletter}

    Please ensure:
    0. Title should be in question form. subtitles are free to make question or just sentence.
    1. Consistent tone and style throughout the newsletter
    2. Smooth transitions between sections
    3. Proper formatting and structure
    4. Clear and enggaging languages
    5. No gramatical or spelling errors

    Provide the edited version of the newsletter.
    """
    
    messages = [HumanMessage(content=prompt)]
    writer_llm = ChatOpenAI(model="gpt-4o-mini", temperature=1, max_tokens=8192)
    response = writer_llm.invoke(messages)

    return {"messages": [HumanMessage(content=f"Edited Newsletter:\n\n{response.content}")]}

# %%
workflow = StateGraph(State)
workflow.add_node("editor", edit_newsletter)
workflow.add_node("search_news", search_keyword_news)
workflow.add_node("generate_theme", generate_newsletter_theme)
workflow.add_node("search_sub_themes", search_sub_theme_articles)
workflow.add_node("aggregate", aggregate_results)

for i in range(5):
    node_name = f"write_section_{i}"
    workflow.add_node(node_name, lambda s, i=1: write_newsletter_section(s, s['newsletter_theme'].sub_themes[i]))

workflow.add_edge(START, "search_news")
workflow.add_edge("search_news", "generate_theme")
workflow.add_edge("generate_theme", "search_sub_themes")

for i in range(5):
    workflow.add_edge("search_sub_themes", f"write_section_{i}")
    workflow.add_edge(f"write_section_{i}", "aggregate")

workflow.add_edge("aggregate", "editor")
workflow.add_edge("editor", END)

graph = workflow.compile()

# %%
from util import display_graph

display_graph(graph)

# %%
# keyword = input("Enter a keyword for the newsletter: ")
keyword = "대한민국 윤석열 대통령 탄핵심판"
inputs = {"keyword": keyword}
async for output in graph.astream(inputs, stream_mode="updates"):
    for key, value in output.items():
        print(f"Output from node '{key}':")
        print("----")
        print(value)
    print("\n---\m")
# Out:
# Output from node 'search_news':
# ----
# {'article_titles': ["South Korea's Yoon defends his martial law decree as impeachment ruling nears - The Sun Chronicle", 'Prosecutors compare South Korean president Yoon to a dictator as impeachment trial nears end - NBC News', 'South Korea’s Impeached President Yoon Faces Final Court Hearing - Bloomberg', 'South Korea’s Yoon Suk Yeol defends martial law decree at impeachment trial - AOL', "South Korea's Yoon defends his martial law decree as impeachment ruling nears - ABC News", 'South Korean President Yoon Suk Yeol brought to court for final hearing of impeachment trial - The Audubon County Advocate Journal', 'S. Korea opposition urges court remove Yoon over martial law - The Daily Record', 'South Koreans to Rally as Yoon’s Impeachment Verdict Nears - Bloomberg', 'South Korea’s Yoon defends his martial law decree as impeachment trial nears end - YourCentralValley.com', 'South Korean President Yoon Suk Yeol brought to court for final hearing of impeachment trial (Video) - Social News XYZ']}
#
# ---\m
# Output from node 'generate_theme':
# ----
# {'newsletter_theme': NewsletterThemeOutput(theme="What are the implications of President Yoon's impeachment trial on South Korea's political landscape?", sub_themes=["Analyzing the Role of Martial Law in Yoon Suk Yeol's Governance: A Legal Perspective", "Public Sentiment and Protest Movements: How South Koreans are Reacting to Yoon's Impeachment Trial", 'Comparative Analysis: How Other Democracies Have Handled Presidential Impeachment Trials', "The Impact of Yoon's Presidency on South Korea's International Relations Amid Domestic Turmoil", "Future of South Korean Politics: What Happens After Yoon's Impeachment Verdict?"])}
#
# ---\m
# Output from node 'search_sub_themes':
# ----
# {'sub_theme_articles': {"Analyzing the Role of Martial Law in Yoon Suk Yeol's Governance: A Legal Perspective": [{'title': 'South Korea Martial Law - The Herald Journal', 'image_url': 'https://assets.korearisk.com/uploads/sites/4/2024/12/yoon-martial-law-analysis-featured-935x500.jpg', 'raw_content': 'South Korea Martial Law | World | hjnews.com\nSkip to main content\nYou have permission to edit this image.\nEdit Close\nFacebook\nTwitter\nYouTube\nEmail\nSite search\nSearch\nSign Up\nLog In\nDashboard\nLogout\nMy Account\nDashboard\nProfile\nSaved items\nLogout\nSUBSCRIBE\nSubscribe Today Or get a Day Pass for only $1.99!\nNewsletters Sign up for news in your inbox every day!\nRead the e-Edition\ne-Edition How-To\nSubscriber Services\nSubscribe\nManage Subscription (Pay Your Bill, Vacation Request, Update Account Info)\nSubscriber Savings\nNewsletters\nContact Customer Service\nNews\nAccidents & Disaster\nBusiness\nCrime Courts\nEducation\nGovernment\nLocal News\nNation\nWorld\nWildfires\nSports\nSchool Sports\nUSU Sports\nCollege\nLocal Sports\nUtah Jazz\nNational Sports\nFeatures\nSubmit a Feature Idea\nSpecial Sections\nMilestones\nAnniversaries\nBirthdays\nWeddings\nSubmissions\nObituaries\nPlace an Obituary\nOpinion\nLetters to the Editor\nLetters\nPolls\nEvents\nPromote Your Event\nClassifieds\nPlace an ad\nMarketplace\nSearch our job listings\nLegal Notices\nJobs\nContests\nOur Publications\nThe Herald Journal\nNews-Examiner\nTremonton Leader\nPreston Citizen\nBusiness Directory\nMake An Announcement\nAnniversary\nBirthdays\nMissionary\nWedding\nSite Services\nGet our newsletters\nAbout Us\nContact Us\nFAQs\nPlace A Classified Ad\nAdd A Calendar Event\nBrowse the Archives\nThe Herald Journal\nNews-Examiner\nThe Leader\nPreston Citizen\nBear Laker\nLatest E-Edition\nThe Herald Journal\nLatest Special Sections\nManage Your Subscription\nSaturday, March 1, 2025\nPrint Edition\ne-Edition How-To\nFacebook\nTwitter\nYouTube\nEmail\n25°\nMenu\nSearch\nSite search\nSearch\nOpen user controls\nLog In Using Your Account\nLog In\nDon\'t have an account? Sign Up Today\nMy Account\nDashboard\nProfile\nSaved items\nLogout\nSign Up\nLog In\nDashboard\nLogout\nMy Account\nDashboard\nProfile\nSaved items\nLogout\nSUBSCRIBE\nHome\nNews\nWildfires\nSports\nFeatures\nSpecial Sections\nMilestones\nObits\nPlace an Obituary\nOpinion\nEvents\nClassifieds\nJobs\nSubscriber Savings\nContests\nReaders\' Choice\n$5,000 Grocery Sweepstakes\nCar Payments Sweeps\nCirculars\nShare This\nFacebook\nTwitter\nWhatsApp\nSMS\nEmail\nAP\nSouth Korea Martial Law\nAhn Young-joon - AP\nMar 1, 2025\n18 mins ago\n0\nFacebook\nTwitter\nWhatsApp\nSMS\nEmail\nPrint\nCopy article link\nSave\nProtesters march during a rally calling for impeached South Korean President Yoon Suk Yeol to step down in Seoul, South Korea, Saturday, March 1, 2025. The letters read "Dismiss Yoon Suk Yeol."\nAhn Young-joon - AP\nTags\nImpeachment\nPolitics\nProtests And Demonstrations\nFacebook\nTwitter\nWhatsApp\nSMS\nEmail\nPrint\nCopy article link\nSave\n×\nPost a comment as anonymous\nEmoticons\n[smile]\n[beam]\n[wink]\n[sad]\n[cool]\n[innocent]\n[rolleyes]\n[whistling]\n[lol]\n[huh]\n[tongue]\n[love]\n[sleeping]\n[yawn]\n[unsure]\n[angry]\n[blink]\n[crying]\n[ohmy]\n[scared]\n[sleep]\n[sneaky]\n[tongue_smile]\n[thumbdown]\n[thumbup]\n[censored]\n[happybirthday]\n[ban]\n[spam]\n[offtopic]\n[batman]\n[ninja]\n[pirate]\n[alien]\nComment Text\nCancel\nPost comment\n×Your comment has been submitted.\nanonymous\n×\nReport\nCancel\nReport Abuse\n×Reported\n×There was a problem reporting this.\n×\nWatch this discussion. Stop watching this discussion.\nWatch this discussion\nGet an email notification whenever someone contributes to the discussion\nNotifications from this discussion will be disabled.\nCancel\nStart watching Stop watching\n(0) comments\nWelcome to the discussion.\nLog In\nWe welcome comments, however there are some guidelines:\nKeep it Clean: Please avoid obscene, vulgar, lewd, rac ...
#
# ---\m
# Output from node 'write_section_1':
# ----
# {'results': {"Public Sentiment and Protest Movements: How South Koreans are Reacting to Yoon's Impeachment Trial": '**국내 여론과 시위 운동: 윤 대통령 탄핵 재판에 대한 한국인들의 반응**\n\n2025년 3월 1일, 서울에서 열린 대규모 집회에서 수십만 명의 한국인들이 윤석열 대통령의 탄핵에 대한 재판 결과를 기다리며 집결했습니다. 서울 경찰에 따르면, 약 35만 명이 광화문 광장과 국회의사당 근처에서 행진할 예정입니다. 집회 참가자들은 "윤석열을 파면하라"는 구호를 외치며 목소리를 높였습니다. 이러한 대규모 시위는 윤 대통령의 군사법 및 헌법 위반에 대한 여론의 강한 반발을 반영하며, 과거의 군사독재 시절을 상기시키고 있습니다.\n\n기사 이미지에서는 시위자들이 윤석열 대통령의 얼굴이 그려진 가면을 착용하고 있는 모습이 담겨 있어, 그들이 표출하는 반대 의견의 강도를 더욱 실감나게 전달합니다. 특히, 시위자들은 "탄핵하라"와 같은 문구를 적은 현수막을 들고 있으며, 이는 한국 사회가 정치적 불만을 표출하는 기회로 삼고 있음을 보여줍니다.\n\n반면, 윤 대통령의 지지자들도 집회에 참여하고 있으며 "윤석열 대통령을 지켜주자"는 구호를 외치며 지지를 표명했습니다. 이들은 야권의 탄핵 시도가 자신들의 정치적 의지를 왜곡하고 있다고 주장하며, 정부의 불법적인 개입에 대한 저항의 필요성을 강조하고 있습니다. 이 두 극단적인 입장을 가진 집회는 현재 한국 사회의 갈등을 심화시키고 있음을 나타냅니다.\n\n법원이 윤 대통령의 탄핵 여부에 대한 최종 결정을 내릴 때, 한국 국민들은 이 중요한 순간에 개인적 신념과 정치적 입장을 명확히 밝혀내는 데 주력하고 있습니다. 이러한 상황은 단순히 정치적 사건이 아니라, 한국 사회의 민주적 가치와 시민의 권리를 수호하기 위한 끊임없는 투쟁의 연장선임을 잊지 말아야 합니다.'}}
#
# ---\m
# Output from node 'write_section_0':
# ----
# {'results': {"Public Sentiment and Protest Movements: How South Koreans are Reacting to Yoon's Impeachment Trial": '### 뉴스레터 섹션: "공공 여론과 시위 운동: 윤 대통령의 탄핵 재판에 대한 한국인들의 반응"\n\n최근 윤석열 대통령의 탄핵 재판이 심각한 공공 여론의 변화를 이끌어내고 있습니다. 2025년 3월 1일 대규모 시위가 서울에서 열렸으며, 약 35만 명이 참여할 것으로 예상됩니다. 이는 윤 대통령이 군사 법령을 선언한 것에 대한 대규모 반발로 해석됩니다. 서울 경찰청에 따르면, 시민들은 광화문 광장과 국회 주변에서 행진할 계획이라고 전했습니다. 이러한 시위는 윤 대통령의 탄핵 여부가 결정되는 중요한 시점에서 열리며, 국민의 의견이 어떻게 시위 및 정치적 전환으로 이어지고 있는지를 보여줍니다.\n\n시위의 상징적 이미지는 매우 인상적입니다. 시위에 참석한 한 참여자는 윤 대통령의 가면을 쓰고 "윤석열을 해임하라"는 문구가 적힌 플래카드를 들고 있습니다. 이는 그가 대통령으로서의 역할을 계속할 수 없다는 여론을 대변합니다. 또한 반대의 목소리도 존재하여, 일부 지지자들은 "윤석열 대통령을 지켜보자!"라는 구호를 외치며 그를 변호하고 있습니다. 이러한 대조적인 장면은 한국 사회의 분열된 감정을 잘 보여줍니다.\n\n탄핵의 최종 결정이 내려질 이 시점은 과거의 군사적 통제와 행정의 만연을 다시금 상기시킵니다. 많은 시민들은 이번 사건을 통해 민주주의와 시민의 권리에 대한 의식을 강화하고 있으며, 공공 문제에 대한 참여와 의견 표현의 중요성을 강조하고 있습니다. 윤석열 대통령과 그 지지자들 사이의 긴장감은 앞으로 어떻게 전개될지 귀추가 주목됩니다.\n\n결론적으로, 윤 대통령의 탄핵 재판은 단순한 정치적 사건을 넘어서, 한국 사회에서의 공공 여론과 시민 참여의 중대한 전환점을 나타내고 있습니다. 국민들은 자신의 목소리를 높이기 위해 거리로 나서고 있으며, 이는 앞으로의 정치적 방향에 중대한 영향을 미칠 것입니다.'}}
#
# ---\m
# Output from node 'write_section_2':
# ----
# {'results': {"Public Sentiment and Protest Movements: How South Koreans are Reacting to Yoon's Impeachment Trial": '## 공적 여론과 시위 운동: 윤 대통령 탄핵 재판에 대한 한국 국민의 반응\n\n2025년 3월 1일, 서울에서 윤석열 대통령의 탄핵 여부에 대한 판결이 임박함에 따라, 수십만명이 모이는 대규모 시위가 예정되어 있습니다. 서울 경찰청은 이날 약 35만 명의 인파가 광화문 광장과 국회 인근에서 집회할 것이라 예상하고 있습니다. 이러한 시위는 최근 운동 중 가장 규모가 큰 집회로, 윤 대통령의 군사법령 선언과 탄핵 논란에 대한 불만이 주된 원인입니다. **Bloomberg**의 보도에 따르면, 많은 사람들이 "윤석열 즉각 탄핵하라"라는 구호를 외치며 마스크를 착용한 모습으로 거리로 나설 예정입니다.\n\n또한, 집회 현장에는 그의 지지를 표하는 시민들도 있는 가운데, "윤석열을 보호하자!"라는 문구가 적힌 플래카드를 든 이들의 모습도 확인되었습니다. 이는 두 진영 간의 심각한 분열을 드러내며, 사회적 긴장감을 더욱 고조시키고 있습니다. **Herald Journal**와 **Goshen News**는 이러한 시위가 단순한 정치적 움직임을 넘어서, 한국 사회의 공적 여론을 직접적으로 반영하고 있음을 강조하였습니다.\n\n특히, 윤 대통령의 탄핵소추는 한국 현대 정치사에서 중요한 여론의 척도로 작용하고 있으며, 많은 사람들은 이번 판결이 대한민국의 민주주의에 큰 전환점이 될 것으로 예측하고 있습니다. **AP 통신**의 사진 속에는 윤석열 마스크를 쓴 시위대의 모습이 담겨 있어, 이러한 시위가 개인의 정체성을 넘어선 집단적인 저항의 상징으로 자리잡고 있음을 보여줍니다.\n\n전국적으로 퍼지는 이러한 집회들은 단순한 정치적 요구 이상으로, 한국 사회 전반의 정치적 참여를 강화하고 있으며, 향후의 정치적 행보에 중대한 영향을 미칠 것으로 예상되고 있습니다. 현재의 갈등은 한국 사회가 직면한 복잡한 사회적, 정치적 쟁점을 반영하며, 이로 인해 다양한 의견과 목소리가 더욱 활발히 표출될 것으로 보입니다.\n\n앞으로의 하루가 한국 사회의 미래를 가늠할 중요한 시점이 될 것입니다. 한국의 정치적 운동이 어디로 향할지 귀추가 주목됩니다.'}}
#
# ---\m
# Output from node 'write_section_3':
# ----
# {'results': {"Public Sentiment and Protest Movements: How South Koreans are Reacting to Yoon's Impeachment Trial": '**공공 여론과 protest 운동: 윤 대통령 탄핵 재판에 대한 한국인들의 반응**\n\n2025년 3월 1일, 서울에서 윤석열 대통령의 탄핵 판결이 가까워짐에 따라 수많은 한국 시민들이 집결할 준비를 하고 있습니다. 블룸버그에 따르면, 서울경찰청은 약 35만 명이 서울 주요 랜드마크인 광화문 광장과 국회 근처에서 행진할 것으로 예상하고 있습니다. 이는 윤 대통령의 군사 법령 선언으로 인한 탄핵 소송이 진행되는 동안 발생하는 가장 큰 시위 중 하나로, 시민들의 강력한 시위를 반영하고 있습니다.\n\n**여론의 양극화**\n이번 시위에는 반대 여론도 존재합니다. 같은 날, 윤 대통령을 지지하는 집회가 진행되고 있으며, 지지자들은 "윤석열 대통령을 지켜주자"는 메시지를 전달하고 있습니다. 이러한 상반된 움직임은 한국 사회 내에서의 정치적 갈등을 심화시키고 있습니다. 한국일보의 사진에서는 마스크를 쓴 시위대원들이 "윤석열을 탄핵하라"는 구호를 외치는 모습이 포착되었습니다. 이들은 임박한 탄핵 판결에 대한 불안감과 이에 대한 저항 의지를 드러내고 있습니다.\n\n**시민 참여의 중요성**\n시민들은 이러한 대규모 시위에 참여함으로써 자신의 의견을 적극적으로 표출하고 있으며, 이는 민주주의의 기본 요소인 표현의 자유를 강화하는 하나의 방법으로 볼 수 있습니다. 저널리스트 Ahn Young-joon은 반대 시위자들의 모습과 그들의 열망을 잘 담아냈습니다. 이러한 시각적 요소는 공공 여론이 얼마나 강력하게 형성되고 있는지를 잘 보여주고 있습니다.\n\n**이제 곧 판결이 나올 예정**\n이번 주에 예정된 판결은 양 측의 주장의 정당성과 사회적 반응을 부각시킬 것입니다. 윤 대통령의 정치적 운명은 이번 탄핵 재판의 결과에 따라 좌우될 뿐만 아니라, 한국의 정치적 환경 전반에도 영향을 미칠 것으로 예상됩니다. 여론의 일치를 이루기 어려운 상황 속에서, 이러한 집회와 시위가 앞으로의 정치적 진행에 어떤 영향을 미칠지 주목할 필요가 있습니다.\n\n시민들의 적극적인 참여와 감정이 복잡하게 얽혀 있는 이 시점에서, 우리는 늘 함께하며 민주주의를 지켜나가고자 하는 한국인들의 의지를 느낄 수 있습니다.'}}
#
# ---\m
# Output from node 'write_section_4':
# ----
# {'results': {"Public Sentiment and Protest Movements: How South Koreans are Reacting to Yoon's Impeachment Trial": '### 공공 여론과 시위 운동: 윤 대통령 탄핵 재판에 대한 한국인의 반응\n\n최근 한국 사회는 윤석열 대통령의 탄핵 재판을 둘러싸고 뜨거운 논란이 일고 있습니다. суд이 최종 결정을 내리기 전, 수십만 명의 시민들이 서울 도심에서 집회를 열기로 결정했습니다. 350,000명 이상의 인원이 서울의 주요 랜드마크들, 특히 광화문 광장과 국회 근처에서 시위를 벌일 예정입니다. 이는 윤 대통령이 무법적으로 선언한 \'계엄령\'에 대한 반대의 목소리를 높이기 위한 행동입니다.\n\n![대규모 시위 중](https://www.apimages.com/metadata/Index/South-Korea-Martial-Law/43f8d1c9b5a045338a8be4f5f21fb9a4/1/0)  \n*시위 중인 한 시민이 윤 대통령의 마스크를 쓰고 반대의 뜻을 나타내고 있습니다. (출처: Ahn Young-joon/AP)*\n\n시위 참가자들은 "윤석열 해임하라"는 구호를 외치며 국민의 의사를 대변하고 있으며, 이 같은 결집은 윤 대통령의 정치적 생명과 향후 국정 운영에 중대한 영향을 미칠 것으로 보입니다. 개인적으로 여론조사를 통해 확인된 바에 따르면, 국민들은 윤 대통령의 탄핵을 지지하며 새로운 선거를 촉구하고 있습니다.\n\n![윤석열 지지 집회](https://www.apimages.com/metadata/Index/South-Korea-Martial-Law/43f8d1c9b5a045338a8be4f5f21fb9a4/2/0)  \n*윤 대통령을 지지하는 이들도 있지만, 이들의 수는 상대적으로 적습니다. (출처: Ahn Young-joon/AP)*\n\n한편, 대통령의 지지 세력인 일부 집회 참가자들은 "윤석열을 보호하자"라는 구호를 외치며 그의 재판에 반대하고 있습니다. 이들은 윤 대통령의 정책들이 정부에 필요한 조치이며, 그의 탄핵이 정치적 음모에 의해 이루어지고 있다고 주장합니다.\n\n최근 여론은 두 갈래로 나뉘어 있으며, 각각의 집회와 시위는 정치적 긴장감을 더하고 있습니다. 여론 조사에서 나타난 바에 따르면, 대다수의 시민들은 윤 대통령의 탄핵을 지지하며, 이는 한국 정치에서 중요하고도 복잡한 상황을 보여주고 있습니다.\n\n이와 같은 현상은 앞으로의 정치적 결정들이 어떤 방향으로 나아갈지에 대한 국민의 불확실함을 반영한다고 할 수 있습니다. 우리는 전개되는 상황을 주의 깊게 지켜보아야 할 것입니다.'}}
#
# ---\m
# Output from node 'aggregate':
# ----
# {'messages': [HumanMessage(content='Generated Newsletter:\n\n# What are the implications of President Yoon\'s impeachment trial on South Korea\'s political landscape?\n\n## Public Sentiment and Protest Movements: How South Koreans are Reacting to Yoon\'s Impeachment Trial\n### 공공 여론과 시위 운동: 윤 대통령 탄핵 재판에 대한 한국인의 반응\n\n최근 한국 사회는 윤석열 대통령의 탄핵 재판을 둘러싸고 뜨거운 논란이 일고 있습니다. суд이 최종 결정을 내리기 전, 수십만 명의 시민들이 서울 도심에서 집회를 열기로 결정했습니다. 350,000명 이상의 인원이 서울의 주요 랜드마크들, 특히 광화문 광장과 국회 근처에서 시위를 벌일 예정입니다. 이는 윤 대통령이 무법적으로 선언한 \'계엄령\'에 대한 반대의 목소리를 높이기 위한 행동입니다.\n\n![대규모 시위 중](https://www.apimages.com/metadata/Index/South-Korea-Martial-Law/43f8d1c9b5a045338a8be4f5f21fb9a4/1/0)  \n*시위 중인 한 시민이 윤 대통령의 마스크를 쓰고 반대의 뜻을 나타내고 있습니다. (출처: Ahn Young-joon/AP)*\n\n시위 참가자들은 "윤석열 해임하라"는 구호를 외치며 국민의 의사를 대변하고 있으며, 이 같은 결집은 윤 대통령의 정치적 생명과 향후 국정 운영에 중대한 영향을 미칠 것으로 보입니다. 개인적으로 여론조사를 통해 확인된 바에 따르면, 국민들은 윤 대통령의 탄핵을 지지하며 새로운 선거를 촉구하고 있습니다.\n\n![윤석열 지지 집회](https://www.apimages.com/metadata/Index/South-Korea-Martial-Law/43f8d1c9b5a045338a8be4f5f21fb9a4/2/0)  \n*윤 대통령을 지지하는 이들도 있지만, 이들의 수는 상대적으로 적습니다. (출처: Ahn Young-joon/AP)*\n\n한편, 대통령의 지지 세력인 일부 집회 참가자들은 "윤석열을 보호하자"라는 구호를 외치며 그의 재판에 반대하고 있습니다. 이들은 윤 대통령의 정책들이 정부에 필요한 조치이며, 그의 탄핵이 정치적 음모에 의해 이루어지고 있다고 주장합니다.\n\n최근 여론은 두 갈래로 나뉘어 있으며, 각각의 집회와 시위는 정치적 긴장감을 더하고 있습니다. 여론 조사에서 나타난 바에 따르면, 대다수의 시민들은 윤 대통령의 탄핵을 지지하며, 이는 한국 정치에서 중요하고도 복잡한 상황을 보여주고 있습니다.\n\n이와 같은 현상은 앞으로의 정치적 결정들이 어떤 방향으로 나아갈지에 대한 국민의 불확실함을 반영한다고 할 수 있습니다. 우리는 전개되는 상황을 주의 깊게 지켜보아야 할 것입니다.\n\n', additional_kwargs={}, response_metadata={}, id='ebb64578-19ef-439e-944d-2083b7541844')]}
#
# ---\m
# Output from node 'editor':
# ----
# {'messages': [HumanMessage(content='Edited Newsletter:\n\n# What Are the Implications of President Yoon\'s Impeachment Trial on South Korea\'s Political Landscape?\n\n## How Are South Koreans Reacting to Yoon\'s Impeachment Trial?\n\nThe recent impeachment trial of President Yoon Suk-yeol has ignited intense debate across South Korea. As the nation\'s political fate hangs in the balance, hundreds of thousands of citizens are expected to gather for demonstrations in the heart of Seoul. Over 350,000 participants are anticipated to converge on key landmarks, especially Gwanghwamun Square and the National Assembly, to voice their opposition against President Yoon’s alleged declaration of a \'state of emergency.\'\n\n![대규모 시위 중](https://www.apimages.com/metadata/Index/South-Korea-Martial-Law/43f8d1c9b5a045338a8be4f5f21fb9a4/1/0)  \n*During a protest, one citizen dons a mask portraying President Yoon to express dissent. (Source: Ahn Young-joon/AP)*\n\nDemonstrators are chanting slogans like "Remove Yoon Suk-yeol," seeking to represent the will of the people. This surge of mobilization is likely to have a significant impact on President Yoon\'s political future and the governance of the country. Recent polls indicate strong public support for his impeachment, with many citizens calling for new elections.\n\n![윤석열 지지 집회](https://www.apimages.com/metadata/Index/South-Korea-Martial-Law/43f8d1c9b5a045338a8be4f5f21fb9a4/2/0)  \n*While there are supporters for President Yoon, their numbers are relatively small. (Source: Ahn Young-joon/AP)*\n\nIn contrast, a smaller faction of demonstrators—aligned with the president—has been rallying under the banner "Protect Yoon Suk-yeol." These supporters argue that his policies are necessary for the government and assert that the impeachment process is driven by political conspiracies.\n\nThe public sentiment is sharply divided, escalating the political tensions in the country. Survey results reveal that a majority of citizens support the impeachment, reflecting a critical and complex moment in South Korean politics.\n\nThis situation embodies the uncertainty that the public feels regarding future political decisions. It is essential to closely monitor the unfolding events as they will likely shape the trajectory of governance and democracy in South Korea.', additional_kwargs={}, response_metadata={}, id='59eeb214-1a88-44ec-9c9c-e0dc098665d5')]}
#
# ---\m

# %%
# 대한민국 윤석열 대통령 탄핵심판
